# %%
import os
import pandas as pd
from scipy import stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score
import math
from numpy import mean
from numpy import std
from numpy import absolute
from numpy import cov
import numpy as np
import inspect
from sklearn.linear_model import LogisticRegression
from google.colab import drive
drive.mount('/content/drive')
import glob

from random import *
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_curve
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Project271B
# Out:
# /content/drive/MyDrive/Project271B

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('framingham.csv')
print(df.shape)
print(df.columns[df.isna().any()].tolist())
na_cols = df.columns[df.isna().any()].tolist()
# Out:
# (4238, 16)
# ['education', 'cigsPerDay', 'BPMeds', 'totChol', 'BMI', 'heartRate', 'glucose']

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
# cursmoker, sys, dias
#df = df.drop(columns=['currentSmoker', 'sysBP','diaBP'])

# %%
indices_to_drop = []
for index,row in df.iterrows():
  if row.isna().sum()>0:
    indices_to_drop.append(index)

# %%
df2 = df.drop(indices_to_drop)

# %% [markdown]
# Handling missing values

# %%
df2.isna().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
# %cd main
# Out:
# /content/drive/My Drive/Project271B/main

# %%
df2.to_csv('pp.csv')

# %%
# df2.to_excel("final_data.xlsx")

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-35c782233b00> in <module>
# ----> 1 from sklearn.model_selection import train_test_spl
#
# ImportError: cannot import name 'train_test_spl' from 'sklearn.model_selection' (/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
y = df2['TenYearCHD']
X = df2
X = df2.drop('TenYearCHD', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35, random_state = 0)
# %cd main

# %%
train = pd.concat([X_train, y_train], axis=1)

# %%
train.to_csv('train.csv')
X_test.to_csv('X_test.csv')
# y_train.to_csv('y_train.csv')
y_test.to_csv('y_test.csv')

# %%
y.head()

# %%
X_train.shape
