# %%
import os
import pandas as pd
from scipy import stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score
import math
from numpy import mean
from numpy import std
from numpy import absolute
from numpy import cov
import numpy as np
import inspect
from sklearn.linear_model import LogisticRegression
from google.colab import drive
drive.mount('/content/drive')
import glob

from random import *
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_curve
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Project271B
# Out:
# /content/drive/MyDrive/Project271B

# %%
df = pd.read_csv('framingham.csv')
print(df.shape)
print(df.columns[df.isna().any()].tolist())
na_cols = df.columns[df.isna().any()].tolist()
# Out:
# (4238, 16)
# ['education', 'cigsPerDay', 'BPMeds', 'totChol', 'BMI', 'heartRate', 'glucose']

# %%
df = df.drop(columns=['glucose'])

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# TenYearCHD           0
# dtype: int64

# %%
# cursmoker, sys, dias
#df = df.drop(columns=['currentSmoker', 'sysBP','diaBP'])

# %%
indices_to_drop = []
for index,row in df.iterrows():
  if row.isna().sum()>0:
    indices_to_drop.append(index)

# %%
df2 = df.drop(indices_to_drop)

# %% [markdown]
# Handling missing values

# %%
df2.isna().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# TenYearCHD         0
# dtype: int64

# %%
df2.shape
# Out:
# (3987, 15)

# %%
# mean_education = df2['education'].mean()
# df2['education'].fillna(value=mean_education, inplace=True)

# %%
# mode_cigsPerDay = df2['cigsPerDay'].mode()
# mode_cigsPerDay = mode_cigsPerDay.mean()
# df2['cigsPerDay'].fillna(value=mode_cigsPerDay, inplace=True)

# %%
# mode_BPmeds = df2['BPMeds'].mode()
# mode_BPmeds = mode_BPmeds.mean()
# df2['BPMeds'].fillna(value=mode_BPmeds, inplace=True)

# %%
# mode_BMI = df2['BMI'].mode()
# mode_BMI = mode_BMI.mean()
# df2['BMI'].fillna(value=mode_BMI, inplace=True)

# %%
# mean_totChol = df2['totChol'].mean()
# df2['totChol'].fillna(value=mean_totChol, inplace=True)

# %%
# mean_glucose = df2['glucose'].mean()
# df2['glucose'].fillna(value=mean_glucose, inplace=True)

# %%
# mode_heartRate = df2['heartRate'].mode()
# mode_heartRate = mode_heartRate.mean()
# df2['heartRate'].fillna(value=mode_heartRate, inplace=True)

# %%
df2.shape
# Out:
# (3987, 15)

# %%
from sklearn.model_selection import train_test_split 
y = df2['TenYearCHD']
X = df2
X = df2.drop('TenYearCHD', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)

# %%
X_train.to_csv('xtrain_dropped.csv')
X_test.to_csv('xest_dropped.csv')
y_train.to_csv('ytrain_dropped.csv')
y_test.to_csv('ytest_dropped.csv')

# %%
df2.to_csv('dropped_df_nn.csv')
